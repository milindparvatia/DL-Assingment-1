# %% [markdown]
# # Assingment 1

# %%
import tensorflow as tf
AUTOTUNE = tf.data.experimental.AUTOTUNE
import numpy as np
import pandas as pd

import os
import tensorflow_datasets as tfds
import pathlib
import shutil
import tempfile

from  IPython import display
from matplotlib import pyplot as plt
import matplotlib.image as mpimg

# %%
train_df = pd.read_csv('train_data.csv')
pd.set_option('display.max_columns', None)
train_df.head(10)
# Out:
#         filename  person_id  series  tilt  pan
# 0   face_790.jpg          5       1   -15   30
# 1  face_2445.jpg          5       1     0  -75
# 2  face_2266.jpg          5       2   -15  -60
# 3  face_2713.jpg          5       2     0  -90
# 4  face_2016.jpg          5       2    15  -75
# 5  face_2522.jpg          5       1    30   60
# 6  face_1254.jpg          5       2    15  -15
# 7  face_2754.jpg          5       1    15  -45
# 8   face_201.jpg          5       2    30  -90
# 9   face_931.jpg          5       1    15  -30

# %%
test_df = pd.read_csv('test_data.csv')
test_df.head(10)
# Out:
#         filename  person_id  series
# 0    face_33.jpg          2       1
# 1  face_2148.jpg          2       2
# 2  face_2119.jpg          2       1
# 3  face_1262.jpg          2       1
# 4   face_516.jpg          2       2
# 5  face_1530.jpg          2       2
# 6   face_464.jpg          2       2
# 7  face_1971.jpg          2       1
# 8    face_92.jpg          2       1
# 9   face_921.jpg          2       2

# %%
# tempdir = pathlib.Path(tempfile.mkdtemp())
# print(tempdir)

# train_images_loc = '/Users/milind/OneDrive - RMIT University/sem3/DL/DL-Assingment-1/train_images/'
# test_images_loc = '/Users/milind/OneDrive - RMIT University/sem3/DL/DL-Assingment-1/test_images/'

src = 'modified_data'
curr_dir = os.listdir(src)

train_data_dir = pathlib.Path('/Users/milind/OneDrive - RMIT University/sem3/DL/DL-Assingment-1/train_images/')
test_data_dir = pathlib.Path('/Users/milind/OneDrive - RMIT University/sem3/DL/DL-Assingment-1/test_images/')

print(train_data_dir)
print(test_data_dir)
# Out:
# /Users/milind/OneDrive - RMIT University/sem3/DL/DL-Assingment-1/train_images
# /Users/milind/OneDrive - RMIT University/sem3/DL/DL-Assingment-1/test_images

# %%
train_image_count = len(list(train_data_dir.glob('*.jpg')))
print(train_image_count)
test_image_count = len(list(test_data_dir.glob('*.jpg')))
print(test_image_count)
# Out:
# 2325
# 465

# %%
for file_name in train_df.iloc[:, 0]:
    full_file_name = os.path.join(src, file_name)
    if os.path.isfile(full_file_name):
        shutil.copy(full_file_name, train_data_dir)
        
for file_name in test_df.iloc[:, 0]:
    full_file_name = os.path.join(src, file_name)
    if os.path.isfile(full_file_name):
        shutil.copy(full_file_name, test_data_dir)

# %%
plt.figure(figsize=(15,15))
for i in range(16):
    plt.subplot(4,4,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    image = mpimg.imread(train_data_dir/train_df['filename'].iloc[i]) # images are color images
    plt.imshow(image)
    # The CIFAR labels happen to be arrays, 
    # which is why you need the extra index
    plt.title(train_df['filename'].iloc[i])
    plt.xlabel(train_df['tilt'].iloc[i])
    plt.ylabel(train_df['pan'].iloc[i])
plt.show()

# %% [markdown]
# # preprocessing Images

# %%
batch_size = 32
img_height = 144
img_width = 192

# %%
from collections import Counter
unique_classes = Counter(list(zip(train_df.tilt, train_df.pan))).keys() # equals to list(set(words))

train_df['class'] = list(zip(train_df.tilt, train_df.pan))

path_images_class = '/Users/milind/OneDrive - RMIT University/sem3/DL/DL-Assingment-1/test_images/'

train_df.head(5)
# Out:
#         filename  person_id  series  tilt  pan       class
# 0   face_790.jpg          5       1   -15   30   (-15, 30)
# 1  face_2445.jpg          5       1     0  -75    (0, -75)
# 2  face_2266.jpg          5       2   -15  -60  (-15, -60)
# 3  face_2713.jpg          5       2     0  -90    (0, -90)
# 4  face_2016.jpg          5       2    15  -75   (15, -75)

# %%
for i in list(unique_classes):
    pathlib.Path(path_images_class+str(i)).mkdir(parents=True, exist_ok=True)    
    
    for index, row in train_df.iterrows():
        if row['class'] in [i]:
             shutil.copy(train_data_dir/row['filename'],
                     path_images_class+str(i))

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    path_images_class,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size)
# Out:
# Found 2325 files belonging to 93 classes.
# Using 1860 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    path_images_class,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size)
# Out:
# Found 2325 files belonging to 93 classes.
# Using 465 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['(-15, -15)', '(-15, -30)', '(-15, -45)', '(-15, -60)', '(-15, -75)', '(-15, -90)', '(-15, 0)', '(-15, 15)', '(-15, 30)', '(-15, 45)', '(-15, 60)', '(-15, 75)', '(-15, 90)', '(-30, -15)', '(-30, -30)', '(-30, -45)', '(-30, -60)', '(-30, -75)', '(-30, -90)', '(-30, 0)', '(-30, 15)', '(-30, 30)', '(-30, 45)', '(-30, 60)', '(-30, 75)', '(-30, 90)', '(-60, -15)', '(-60, -30)', '(-60, -45)', '(-60, -60)', '(-60, -75)', '(-60, -90)', '(-60, 0)', '(-60, 15)', '(-60, 30)', '(-60, 45)', '(-60, 60)', '(-60, 75)', '(-60, 90)', '(-90, 0)', '(0, -15)', '(0, -30)', '(0, -45)', '(0, -60)', '(0, -75)', '(0, -90)', '(0, 0)', '(0, 15)', '(0, 30)', '(0, 45)', '(0, 60)', '(0, 75)', '(0, 90)', '(15, -15)', '(15, -30)', '(15, -45)', '(15, -60)', '(15, -75)', '(15, -90)', '(15, 0)', '(15, 15)', '(15, 30)', '(15, 45)', '(15, 60)', '(15, 75)', '(15, 90)', '(30, -15)', '(30, -30)', '(30, -45)', '(30, -60)', '(30, -75)', '(30, -90)', '(30, 0)', '(30, 15)', '(30, 30)', '(30, 45)', '(30, 60)', '(30, 75)', '(30,
# ...

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 144, 192, 3)
# (32,)

# %%
train_ds
# Out:
# <BatchDataset shapes: ((None, 144, 192, 3), (None,)), types: (tf.float32, tf.int32)>

# %%
# Standardize the data

# %%
from tensorflow.keras import layers

normalization_layer = tf.keras.layers.experimental.preprocessing.Rescaling(1./255)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixels values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 1.0

# %%
image_batch[0][0][0]
# Out:
# <tf.Tensor: shape=(3,), dtype=float32, numpy=array([0.08235294, 0.07450981, 0.07843138], dtype=float32)>

# %% [markdown]
# # Configure the dataset for performance

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
num_classes = 93

model = tf.keras.Sequential([
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(32, 3, activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

# %%
model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=3
)
# Out:
# Epoch 1/3
# 59/59 [==============================] - 23s 398ms/step - loss: 4.5380 - accuracy: 0.0097 - val_loss: 4.5341 - val_accuracy: 0.0108
# Epoch 2/3
# 59/59 [==============================] - 21s 351ms/step - loss: 4.5232 - accuracy: 0.0188 - val_loss: 4.5151 - val_accuracy: 0.0108
# Epoch 3/3
# 59/59 [==============================] - 21s 349ms/step - loss: 4.1861 - accuracy: 0.0495 - val_loss: 4.0083 - val_accuracy: 0.0366

# %%
# shutil.rmtree(train_images_loc)
# shutil.rmtree(test_images_loc)
